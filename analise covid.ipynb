# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

confirmed = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv", error_bad_lines=False)
confirmed.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '7/16/21', '7/17/21', '7/18/21', '7/19/21', '7/20/21', '7/21/21',
#        '7/22/21', '7/23/21', '7/24/21', '7/25/21'],
#       dtype='object', length=555)

# %%
confirmed= confirmed.rename(columns={'Country/Region': 'Country'})

# %%
brasil = confirmed.query('Country == "Brazil"')
brasil
# Out:
#    Province/State Country     Lat     Long  1/22/20  1/23/20  1/24/20  \
# 30            NaN  Brazil -14.235 -51.9253        0        0        0
#
#     1/25/20  1/26/20  1/27/20  ...   7/13/21   7/14/21   7/15/21   7/16/21  \
# 30        0        0        0  ...  19151993  19209729  19262518  19308109
#
#      7/17/21   7/18/21   7/19/21   7/20/21   7/21/21   7/22/21
# 30  19342448  19376574  19391845  19419437  19473954  19523711
#
# [1 rows x 552 columns]

# %%
teste = brasil.drop(['Province/State', 'Country', 'Lat', 'Long'], axis= 1)

# %%
teste.T.diff().plot()
# Out:
# <AxesSubplot:>

# %%
confirmed_by_country = confirmed.groupby("Country").sum()
confirmed_by_country_teste = confirmed.groupby("Country")
confirmed_by_country.head()
# Out:
#                   Lat       Long  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# Country
# Afghanistan  33.93911  67.709953        0        0        0        0        0
# Albania      41.15330  20.168300        0        0        0        0        0
# Algeria      28.03390   1.659600        0        0        0        0        0
# Andorra      42.50630   1.521800        0        0        0        0        0
# Angola      -11.20270  17.873900        0        0        0        0        0
#
#              1/27/20  1/28/20  1/29/20  ...  7/13/21  7/14/21  7/15/21  \
# Country                                 ...
# Afghanistan        0        0        0  ...   134653   136643   137853
# Albania            0        0        0  ...   132608   132616   132629
# Algeria            0        0        0  ...   147883   148797   149906
# Andorra            0        0        0  ...    14167    14167    14239
# Angola             0        0        0  ...    40138    40327    40530
#
# ...

# %%
df = brasil

# %%
df.squeeze()[4:].plot()
# Out:
# <AxesSubplot:>

# %%
type(confirmed_by_country.loc["Brazil"][2:])
# Out:
# pandas.core.series.Series
